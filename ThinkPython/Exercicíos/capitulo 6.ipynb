# %%
def b(z):
    prod = a(z, z)
    print(z, prod)
    return prod

def a(x, y):
    x = x + 1
    return x * y

def c(x, y, z):
    total = x + y + z
    square = b(total)**2
    return square

x = 1
y = x + 1
print(c(x, y+3, x+y))
# Out:
# 9 90
# 8100

# %%
def ack(m,n):
    if m == 0:
        return n+1
    elif m>0 and n==0:
        return ack(m-1,1)
    else:
        return ack(m-1,ack(m,n-1))

ack(3,4)
# Out:
# 125

# %% [markdown]
# <h2>Podendo ser mais conciso <h2>

# %%
def ack(m,n):
    if m == 0:
        return n+1
    if n==0: # a eliminação de m>0 se dá porque se o programa chegou nessa linha
             # é certo que o M não é ZERO
        return ack(m-1,1)
    return ack(m-1,ack(m,n-1))
    # não tem um outro if porque se os dois if's foram INSATISFEITOS, quer dizer que só resta esse caso!! 
    #por isso, o genio do allen n fez nada

ack(3,4)
